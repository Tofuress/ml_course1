# %%
import numpy as np

# %%
import pandas as pd

# %%
pwd
# Out:
# 'D:\\Users\\Sofia\\Documents\\scripts\\ml_course\\03-Pandas'

# %%
ls
# Out:
#  ’®¬ ў гбва®©бвўҐ D Ё¬ҐҐв ¬ҐвЄг DATA
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : E844-7913
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ D:\Users\Sofia\Documents\scripts\ml_course\03-Pandas
#
# 24.10.2025  11:14    <DIR>          .
# 24.10.2025  11:14    <DIR>          ..
# 24.10.2025  11:08    <DIR>          .ipynb_checkpoints
# 28.10.2020  14:22    <DIR>          __pycache__
# 18.01.2022  17:58           568я368 00-Series.ipynb
# 31.05.2025  17:09           144я644 01-DataFrames.ipynb
# 18.01.2022  18:06           195я623 02-Conditional-Filtering.ipynb
# 31.05.2025  17:10           146я090 03-Useful-Methods.ipynb
# 31.05.2025  17:11            66я461 04-Missing-Data.ipynb
# 31.05.2025  17:11           224я682 05-Groupby-Operations-and-MultiIndex.ipynb
# 18.01.2022  18:24            66я225 06-Combining-DataFrames.ipynb
# 18.01.2022  18:27            34я195 07-Text-Methods.ipynb
# 31.05.2025  17:11           106я530 08-Time-Methods.ipynb
# 31.05.2025  17:18           202я222 09-Inputs-and-Outputs.ipynb
# 31.05.2025  17:18           106я734 10-Pivot-Tables.ipynb
# 29.08.2024  19:30            59я007 11-Pandas-Project-Exercise.ipynb
# 24.12.2023  11:31            61я218 12-Pandas-Project-Exercise-Solution.ipynb
# 24.10.2025  11:07            44я545 dataframes_practice.ipynb
# 24.10.2025  11:14            40я553 dataframes_practice1.ipynb
# 04.07.2020  17:39                51 example.csv
# 31.05.2025  17:18             5я024 example.xlsx
# 12.07.2020  12:41        25я112я317 hotel_booking_data.csv
# 07.02.2020  12:26               177 movie_scores.csv
# 01.07.2020  15:56            17я727 mpg.csv
# 31.05.2025  17:17            25я600 my_excel_file.xls
# 04.07.2020  17:58             5я022 my_excel_file.xlsx
# 31.05.2025  17:18                46 new_file.csv
# 26.09.2020  12:05             5я021 new_workbook.xlsx
# 25.09.2020  17:16                51 newfile.csv
# 11.07.2020  12:14            52я132 reshaping_pivot.png
# 02.07.2020  17:56             5я459 RetailSales_BeerWineLiquor.csv
# 06.07.2020  17:10             1я320 Sales_Funnel_CRM.csv
# 26.09.2020  10:40             1я330 sample_table.html
# 31.05.2025  17:18               555 simple.html
# 27.01.2020  14:28            18я752 tips.csv
#               31 д ©«®ў     27я317я681 Ў ©в
#                4 Ї Ї®Є  474я673я381я376 Ў ©в бў®Ў®¤­®

# %%
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df['tip_precentage'] = np.round(100 * df['tip'] / df['total_bill'], 2)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_precentage
# 0    Christy Cunningham  3560325168603410    Sun2959            5.94
# 1        Douglas Tucker  4478071379779230    Sun4608           16.05
# 2        Travis Walters  6011812112971322    Sun4458           16.66
# 3      Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4          Tonya Carter  4832732618637221    Sun2251           14.68
# ..                  ...               ...        ...             ...
# 239       Michael Avila  5296068606052842    Sat2657           20.39
# 240      Monica Sanders  3506806155565404    Sat1766            7.36
# 241          Keith Wong  6011891618747196    Sat3880            8.82
# 242        Dennis Dixon     4375220550950      Sat17            9.82
# 243     Michelle Hardin  3511451626698139    Thur672           15.97
#
# [244 rows x 12 columns]

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_precentage
# 0    Christy Cunningham  3560325168603410    Sun2959            5.94
# 1        Douglas Tucker  4478071379779230    Sun4608           16.05
# 2        Travis Walters  6011812112971322    Sun4458           16.66
# 3      Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4          Tonya Carter  4832732618637221    Sun2251           14.68
# ..                  ...               ...        ...             ...
# 239       Michael Avila  5296068606052842    Sat2657           20.39
# 240      Monica Sanders  3506806155565404    Sat1766            7.36
# 241          Keith Wong  6011891618747196    Sat3880            8.82
# 242        Dennis Dixon     4375220550950      Sat17            9.82
# 243     Michelle Hardin  3511451626698139    Thur672           15.97
#
# [244 rows x 12 columns]

# %%
df.shape
# Out:
# (244, 12)

# %%
df = df.set_index('Payment ID')

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
# ...                      ...                 ...               ...
# Sat2657                 9.68       Michael Avila  5296068606052842
# Sat1766                13.59      Monica Sanders  3506806155565404
# Sat3880                11.34          Keith Wong  6011891618747196
# Sat17                   8.91        Dennis Dixon     4375220550950
# Thur672                 9.39     Michelle Hardin  3511451626698139
#
#             tip_precentage
# Payment ID
# Sun2959               5.94
# Sun4608              16.05
# Sun4458              16.66
# Sun5260              13.98
# Sun2251              14.68
# ...                    ...
# Sat2657              20.39
# Sat1766               7.36
# Sat3880               8.82
# Sat17                 9.82
# Thur672              15.97
#
# [244 rows x 11 columns]

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
#
#             tip_precentage
# Payment ID
# Sun2959               5.94
# Sun4608              16.05
# Sun4458              16.66
# Sun5260              13.98
# Sun2251              14.68

# %%
df = df.reset_index()

# %%
df
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  tip_precentage
# 0                8.49  Christy Cunningham  3560325168603410            5.94
# 1                3.45      Douglas Tucker  4478071379779230           16.05
# 2                7.00      Travis Walters  6011812112971322           16.66
# 3               11.84    Nathaniel Harris  4676137647685994           13.98
# 4                6.15        Tonya Carter  4832732618637221           14.68
# ..                ...                 ...               ...             ...
# 239              9.68       Michael Avila  5296068606052842           20.39
# 240             13.59      Monica Sanders  3506806155565404            7.36
# 241             11.34          Keith Wong  6011891618747196            8.82
# 242              8.91        Dennis Dixon     4375220550950            9.82
# 243              9.39     Michelle Hardin  3511451626698139           15.97
#
# [244 rows x 12 columns]

# %%
df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
#
#             tip_precentage
# Payment ID
# Sun2959               5.94
# Sun4608              16.05
# Sun4458              16.66
# Sun5260              13.98
# Sun2251              14.68

# %%
df.iloc[0:4]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
#
#             tip_precentage
# Payment ID
# Sun2959               5.94
# Sun4608              16.05
# Sun4458              16.66
# Sun5260              13.98

# %%
df.loc[['Sun2959', 'Sun5260']]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun5260                11.84    Nathaniel Harris  4676137647685994
#
#             tip_precentage
# Payment ID
# Sun2959               5.94
# Sun5260              13.98

# %%
df = df.drop('Sun2959', axis=0)

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person        Payer Name         CC Number  \
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# Sun4458                 7.00    Travis Walters  6011812112971322
# Sun5260                11.84  Nathaniel Harris  4676137647685994
# Sun2251                 6.15      Tonya Carter  4832732618637221
# Sun9679                 6.32        Erik Smith   213140353657882
#
#             tip_precentage
# Payment ID
# Sun4608              16.05
# Sun4458              16.66
# Sun5260              13.98
# Sun2251              14.68
# Sun9679              18.62

# %%
one_row = df.iloc[0]

# %%
one_row
# Out:
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                3.45
# Payer Name            Douglas Tucker
# CC Number           4478071379779230
# tip_precentage                 16.05
# Name: Sun4608, dtype: object

# %%
#df = pd.concat([df, pd.DataFrame([one_row])], axis = 0)
df = df._append(one_row)

# %%
df
# Out:
#                 total_bill   tip     sex smoker  day    time  size  \
# Sun4608              10.34  1.66    Male     No  Sun  Dinner   3.0
# Sun4458              21.01  3.50    Male     No  Sun  Dinner   3.0
# Sun5260              23.68  3.31    Male     No  Sun  Dinner   2.0
# Sun2251              24.59  3.61  Female     No  Sun  Dinner   4.0
# Sun9679              25.29  4.71    Male     No  Sun  Dinner   4.0
# ...                    ...   ...     ...    ...  ...     ...   ...
# Payer Name             NaN   NaN     NaN    NaN  NaN     NaN   NaN
# CC Number              NaN   NaN     NaN    NaN  NaN     NaN   NaN
# tip_precentage         NaN   NaN     NaN    NaN  NaN     NaN   NaN
# Sun4608              10.34  1.66    Male     No  Sun  Dinner   3.0
# Sun4608              10.34  1.66    Male     No  Sun  Dinner   3.0
#
#                 price_per_person        Payer Name     CC Number  \
# Sun4608                     3.45    Douglas Tucker  4.478071e+15
# Sun4458                     7.00    Travis Walters  6.011812e+15
# Sun5260                    11.84  Nathaniel Harris  4.676138e+15
# Sun2251                     6.15      Tonya Carter  4.832733e+15
# Sun9679                     6.32        Erik Smith  2.131404e+14
# ...                          ...               ...           ...
# Payer Name                   NaN               NaN           NaN
# CC Number                    NaN               NaN           NaN
# tip_precentage               NaN               NaN           NaN
# Sun4608                     3.45    Douglas Tucker  4.478071e+15
# Sun4608                     3.45    Douglas Tucker  4.478071e+15
#
#                 tip_precentage           Sun4608
# Sun4608                  16.05               NaN
# Sun4458                  16.66               NaN
# Sun5260                  13.98               NaN
# Sun2251                  14.68               NaN
# Sun9679                  18.62               NaN
# ...                        ...               ...
# Payer Name                 NaN    Douglas Tucker
# CC Number                  NaN  4478071379779230
# tip_precentage             NaN             16.05
# Sun4608                  16.05               NaN
# Sun4608                  16.05               NaN
#
# [256 rows x 12 columns]
